# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# C:\Users\SOUMIK\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Tensorflow version: 2.14.0
# GPU detected: []

# %%
data = pd.read_csv(r"C:\Users\SOUMIK\Desktop\CNER Project\archive\ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)
print(num_words, num_tags)
# Out:
# 35179 17

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
word2idx
# Out:
# {'count': 1,
#  'T.': 2,
#  '9.5': 3,
#  'vomiting': 4,
#  'eyesight': 5,
#  'pro-immigrant': 6,
#  'MINUSTAH': 7,
#  '747s': 8,
#  'Bormio': 9,
#  'Ah': 10,
#  'mid-to-late': 11,
#  'Malawian': 12,
#  'let': 13,
#  '220-kilogram': 14,
#  'quarterly': 15,
#  'Bhairahawa': 16,
#  'subsidized': 17,
#  'Comoran': 18,
#  'attendees': 19,
#  'Branko': 20,
#  'Dodger': 21,
#  'Charm': 22,
#  'Abdul-Khalim': 23,
#  'airline': 24,
#  'humidity': 25,
#  'Four-time': 26,
#  'utilities': 27,
#  'downbeat': 28,
#  'Buyat': 29,
#  'crisis-related': 30,
#  'Pensacola': 31,
#  'baked': 32,
#  'statue': 33,
#  'transformer': 34,
#  'defensible': 35,
#  'gala': 36,
#  'Corazon': 37,
#  'floundering': 38,
#  'catastrophe': 39,
#  'hair-raising': 40,
#  'discrepancies': 41,
#  'reclaimed': 42,
#  'fairly': 43,
#  '9.9': 44,
#  'Get': 45,
#  'redeploy': 46,
#  'tabulation': 47,
#  'Cashew': 48,
#  'tit-for-tat': 49,
#  'disburses': 50,
#  'Emma': 51,
#  'neither': 52,
#  'Ganiyev': 53,
#  'barrier': 54,
#  'Evin': 55,
#  'Challenger': 56,
#  'nationalizations': 57,
#  'Cape': 58,
#  'Stosur': 59,
#  'visible': 60,
#  'sacrifices': 61,
#  'Broadcasters': 62,
#  'champion': 63,
#  'Dasain': 64,
#  'Micronesia': 65,
#  'Lewis': 66,
#  'infrared': 67,
#  'adopting': 68,
#  'Joaquin': 69,
#  '2.7': 70,
#  'Thien': 71,
#  'Ashraful': 72,
#  'symbolizing': 73,
#  'thistles': 74,
#  'six-to-11-year-old': 75,
#  'longer-term': 76,
#  'Althing': 77,
#  'Saadi': 78,
#  'Maritime': 79,
#  'corvettes': 80,
#  'Pleshkov': 81,
#  'stumped': 82,
#  'Andrus': 83,
#  'friction': 84,
#  'bomb': 85,
#  'spewing': 86,
#  'disrupts': 87,
#  'nonpermanent': 88,
#  '6,54,000': 89,
#  'militarist': 90,
#  'coldness': 91,
#  'Markos': 92,
#  'Vine': 93,
#  'Armed': 94,
#  'Banaue': 95,
#  'interference': 96,
#  'Exploration': 97,
#  'contingency': 98,
#  'oppose': 99,
#  'Siegouekou': 100,
#  'Tintane': 101,
#  'tandem': 102,
#  'inspect': 103,
#  'Gene': 104,
#  'survive': 105,
#  'Article': 106,
#  'Usmani': 107,
#  'respond': 108,
#  'simmering': 109,
#  'Akhund': 110,
#  'celebrating': 111,
#  'good': 112,
#  'technician': 113,
#  'Happy': 114,
#  'runners': 115,
#  'Japanese': 116,
#  'dancer': 117,
#  'Raipur': 118,
#  'descent': 119,
#  'clarifies': 120,
#  'undrafted': 121,
#  'arising': 122,
#  'doubled': 123,
#  'Mostar': 124,
#  'newly-appointed': 125,
#  'rigid': 126,
#  'esteem': 127,
#  'mercy': 128,
#  'glue': 129,
#  'eastward': 130,
#  'squash': 131,
#  'outbreaks': 132,
#  '22.4': 133,
#  'U.S.-Iraqi': 134,
#  'Badr': 135,
#  'Egyptian': 136,
#  'Italy': 137,
#  'non-believers': 138,
#  'genders': 139,
#  'Baziv': 140,
#  'inoculated': 141,
#  'Rohingya': 142,
#  'miraculous': 143,
#  'Rachel': 144,
#  'Policy': 145,
#  'fast': 146,
#  'far-reaching': 147,
#  'attend': 148,
#  'Inflation': 149,
#  'Reigning': 150,
#  'obstructing': 151,
#  'invaded': 152,
#  'Gration': 153,
#  'Which': 154,
#  'Agu': 155,
#  'decommission': 156,
#  'Asou': 157,
#  'Bakool': 158,
#  'Dick': 159,
#  'flexibility': 160,
#  'longed': 161,
#  'Joint': 162,
#  'basement': 163,
#  'mouse': 164,
#  'overlaps': 165,
#  'Golkar': 166,
#  'containment': 167,
#  'exodus': 168,
#  'eight-legged': 169,
#  'while': 170,
#  'conservative': 171,
#  'RAVALOMANANA': 172,
#  'Clothing': 173,
#  'subsequent': 174,
#  'expansion': 175,
#  'Treatment': 176,
#  'bovine': 177,
#  'jam': 178,
#  'constitute': 179,
#  'NFL': 180,
#  'integrity': 181,
#  'Islamist': 182,
#  'anything': 183,
#  'Parts': 184,
#  'Disease': 185,
#  'acquisition': 186,
#  'Hurricane': 187,
#  'devolution': 188,
#  'fouls': 189,
#  'earnest': 190,
#  'Kalmykia': 191,
#  'Tibetan-American': 192,
#  'Soviets': 193,
#  'Rick': 194,
#  'awaiting': 195,
#  'Emroz': 196,
#  'Yoadimnadji': 197,
#  'extinct': 198,
#  'defer': 199,
#  'incendiary': 200,
#  'chasing': 201,
#  'sampled': 202,
#  'Currently': 203,
#  'Congressman': 204,
#  'dramatizes': 205,
#  'insurgent': 206,
#  'Bi-khim': 207,
#  'disrespectful': 208,
#  'Orbiter': 209,
#  'substation': 210,
#  'U.S.-Venezuelan': 211,
#  'drinking-horn': 212,
#  'Siddiqi': 213,
#  'Cary': 214,
#  'Mientes': 215,
#  'Bulandshahr': 216,
#  'Object': 217,
#  'studying': 218,
#  'Restless': 219,
#  'forth': 220,
#  'conquest': 221,
#  'Ramos-Horta': 222,
#  'revote': 223,
#  'up': 224,
#  'Rory': 225,
#  'retake': 226,
#  'disposing': 227,
#  'enroute': 228,
#  'frequency': 229,
#  'presses': 230,
#  'cremated': 231,
#  'stage': 232,
#  '64-year-old': 233,
#  'calling': 234,
#  'nationalists': 235,
#  'synagogues': 236,
#  'Bert': 237,
#  'goats': 238,
#  'library': 239,
#  'Ramin': 240,
#  'recounting': 241,
#  'husbandry': 242,
#  'America': 243,
#  'weighs': 244,
#  'punished': 245,
#  'saturated': 246,
#  '5.1': 247,
#  'dozen': 248,
#  'meetings': 249,
#  'arranges': 250,
#  'Support': 251,
#  'rotator': 252,
#  'whale': 253,
#  'poaching': 254,
#  'representative': 255,
#  '64-day': 256,
#  'one-yard': 257,
#  '2,200': 258,
#  'Jorge': 259,
#  'Nations-mediated': 260,
#  'pilgrimages': 261,
#  'Match': 262,
#  'Sukhoi': 263,
#  'instructor': 264,
#  'Village': 265,
#  'authenticated': 266,
#  'outpost': 267,
#  'Stop': 268,
#  'Bhutan': 269,
#  'sands': 270,
#  'wounding': 271,
#  'usage': 272,
#  'Judiciary': 273,
#  'occupies': 274,
#  'aggressively': 275,
#  'harder': 276,
#  'Danai': 277,
#  'drug-fueled': 278,
#  'threatening': 279,
#  'surround': 280,
#  'accommodating': 281,
#  '27-20': 282,
#  'clarified': 283,
#  'supports': 284,
#  'non-profit': 285,
#  'Ethiopia': 286,
#  'Posht-e-Rud': 287,
#  'military': 288,
#  'Stock': 289,
#  'picnicking': 290,
#  'Cemetery': 291,
#  'Sinn': 292,
#  'Rada': 293,
#  'wig': 294,
#  'Damascus-based': 295,
#  'renewal': 296,
#  'two-degrees': 297,
#  'extended': 298,
#  '809': 299,
#  'cooler': 300,
#  'dye': 301,
#  'approves': 302,
#  'Afellay': 303,
#  'Executives': 304,
#  'duty-free': 305,
#  'unsound': 306,
#  'Lansana': 307,
#  'free-floating': 308,
#  'Mota': 309,
#  'industrialize': 310,
#  'classic': 311,
#  'Lome': 312,
#  'Blaise': 313,
#  'neo-liberal': 314,
#  'regency': 315,
#  'Talat': 316,
#  'advisories': 317,
#  'conscripted': 318,
#  'Chacon': 319,
#  '413': 320,
#  'quakes': 321,
#  'pre-natal': 322,
#  '48,000': 323,
#  'famine-related': 324,
#  'Uzbek': 325,
#  '246': 326,
#  'detonated': 327,
#  'Unwilling': 328,
#  'commonly': 329,
#  'scrolls': 330,
#  'Orion': 331,
#  '86th': 332,
#  'lull': 333,
#  'communist': 334,
#  'neutralizing': 335,
#  'Mastung': 336,
#  'Raila': 337,
#  'system': 338,
#  'Edgar': 339,
#  'modernize': 340,
#  'student': 341,
#  'shareholder-rights': 342,
#  'independence': 343,
#  'catalyst': 344,
#  'HOPE': 345,
#  'overshadow': 346,
#  'incurred': 347,
#  'Varema': 348,
#  'well-developed': 349,
#  'adolescent': 350,
#  'aboriginal': 351,
#  'Bullitt': 352,
#  'Verveer': 353,
#  'armchair': 354,
#  'centralized': 355,
#  'Actress': 356,
#  'Danes': 357,
#  'tipped': 358,
#  'wells': 359,
#  'impressed': 360,
#  'bruised': 361,
#  'touts': 362,
#  'reservoirs': 363,
#  'Hemisphere': 364,
#  'trailed': 365,
#  'XII': 366,
#  'Ethnomusicologist': 367,
#  'Bahrainian': 368,
#  'underfunded': 369,
#  'Costner': 370,
#  '53-year-old': 371,
#  'Muslim-Croat': 372,
#  'Kanyutkwin': 373,
#  'reconciliation': 374,
#  'courtyard': 375,
#  'form': 376,
#  'agriculture': 377,
#  'Pradip': 378,
#  'University': 379,
#  'priestly': 380,
#  'reluctantly': 381,
#  'Buddhist': 382,
#  'smell': 383,
#  'Shelter': 384,
#  'collision': 385,
#  'car-bombing': 386,
#  'microchips': 387,
#  'Skubiszewski': 388,
#  'Kenyan': 389,
#  'Sofyan': 390,
#  'crossroads': 391,
#  'volcanos': 392,
#  'hurricane-damaged': 393,
#  'Samir': 394,
#  'Anxious': 395,
#  'bunkers': 396,
#  '346': 397,
#  'advertising': 398,
#  'mountainous': 399,
#  'Ladi': 400,
#  'Akmatbayev': 401,
#  'presumably': 402,
#  'quoth': 403,
#  'groups': 404,
#  'regulated': 405,
#  'shop': 406,
#  'networking': 407,
#  'billiard': 408,
#  'exhumation': 409,
#  'cemented': 410,
#  'looters': 411,
#  'spite': 412,
#  'towards': 413,
#  'Baiji': 414,
#  'Fewer': 415,
#  'teenagers': 416,
#  'facilitates': 417,
#  'correspondents': 418,
#  'back-up': 419,
#  'powerful': 420,
#  'Ascension': 421,
#  'misses': 422,
#  'Silva': 423,
#  'Bychkova': 424,
#  'indiscretion': 425,
#  'desalinization': 426,
#  '264': 427,
#  'Progress': 428,
#  'Dravid': 429,
#  'exhaustion': 430,
#  'slicked': 431,
#  'debilitating': 432,
#  'Giving': 433,
#  'willingly': 434,
#  'apparent': 435,
#  'resolve': 436,
#  'kingdom': 437,
#  'Junoon': 438,
#  'India-controlled': 439,
#  'posthumous': 440,
#  'decades-long': 441,
#  'Bibles': 442,
#  'declining': 443,
#  'day': 444,
#  'get': 445,
#  'monk': 446,
#  'Housing': 447,
#  '29th': 448,
#  'Majtenyi': 449,
#  'Samara': 450,
#  'Zhvania': 451,
#  're-launch': 452,
#  'fishery': 453,
#  'pregnant': 454,
#  'admiring': 455,
#  'Coordinator': 456,
#  'Kuala': 457,
#  'Antarctic': 458,
#  'Krajicek': 459,
#  'Dell': 460,
#  'COMMUNICATIONS': 461,
#  'four-tenths': 462,
#  'spawned': 463,
#  'Burgie': 464,
#  'Qari': 465,
#  'undefeated': 466,
#  'liters': 467,
#  'Protestants': 468,
#  'virus-sharing': 469,
#  'partitioned': 470,
#  'menstrual': 471,
#  'P.': 472,
#  'reinvigorate': 473,
#  'Shawal': 474,
#  '250,000-member': 475,
#  'Morelos': 476,
#  'headlights': 477,
#  'firebomb': 478,
#  'Dohuk': 479,
#  'Karradah': 480,
#  'tapered': 481,
#  'Theatre': 482,
#  'absolute': 483,
#  'speeding': 484,
#  'hemispheric': 485,
#  'traditionally': 486,
#  'Oil-rich': 487,
#  'precondition': 488,
#  'Sarawak': 489,
#  'Crumpton': 490,
#  'agree': 491,
#  'Stag': 492,
#  'Georges': 493,
#  'Escravos': 494,
#  'amounts': 495,
#  'Kitts': 496,
#  'Post': 497,
#  'Pilgrims': 498,
#  'does': 499,
#  'shield': 500,
#  '185-million': 501,
#  'harbors': 502,
#  'scrambling': 503,
#  'Sawyer': 504,
#  'dam': 505,
#  'gubernatorial': 506,
#  'Kheir': 507,
#  'Hutton': 508,
#  'admitting': 509,
#  'Baikal': 510,
#  'surprised': 511,
#  'Kosachev': 512,
#  'promotes': 513,
#  'anticipations': 514,
#  'Nominees': 515,
#  'Christi': 516,
#  'weakened': 517,
#  'persecuted': 518,
#  'incoming': 519,
#  'Allan': 520,
#  'granting': 521,
#  'jog': 522,
#  'Weiner': 523,
#  '1.32': 524,
#  'public': 525,
#  'tallies': 526,
#  '225-member': 527,
#  'Dostum': 528,
#  'Roma': 529,
#  'churches': 530,
#  'pandas': 531,
#  'Mandelson': 532,
#  'hasty': 533,
#  'issues': 534,
#  'Kar': 535,
#  'morphine': 536,
#  'Pangandaran': 537,
#  'primary': 538,
#  'proteins': 539,
#  '70s': 540,
#  'tramway': 541,
#  'cocoa': 542,
#  'aggression': 543,
#  'uncertainty': 544,
#  '1890': 545,
#  'CARTOSAT-1': 546,
#  'funds': 547,
#  'unlike': 548,
#  'Estimates': 549,
#  'porcelain': 550,
#  'anthrax': 551,
#  'Wirayuda': 552,
#  'Haqqani': 553,
#  'Bolton': 554,
#  'westward': 555,
#  'ashore': 556,
#  'Cube': 557,
#  'VanAllen': 558,
#  'Indonesia-based': 559,
#  'Annexation': 560,
#  'proximity': 561,
#  'Gerald': 562,
#  'Uddin': 563,
#  'verification': 564,
#  'Fayssal': 565,
#  'Kaduna': 566,
#  '1790': 567,
#  'hurt': 568,
#  'clay': 569,
#  'phrase': 570,
#  'chronic': 571,
#  'Pradel': 572,
#  'Pakistani-sponsored': 573,
#  'wrought': 574,
#  'six-nation': 575,
#  'Missouri': 576,
#  'Leroy': 577,
#  'pledging': 578,
#  'demontrators': 579,
#  'Vedomosti': 580,
#  'Fisher': 581,
#  'Bonaire': 582,
#  'grains': 583,
#  'irreconcilable': 584,
#  'extinguished': 585,
#  'colonized': 586,
#  'militarized': 587,
#  'Torkham': 588,
#  'Administration': 589,
#  'municipalities': 590,
#  'disbursing': 591,
#  '107.41': 592,
#  'man': 593,
#  'firecracker': 594,
#  'IDB': 595,
#  'SHACKLETON': 596,
#  'initially': 597,
#  'Kovalchuk': 598,
#  'Contracted': 599,
#  'paratroopers': 600,
#  'Annunciation': 601,
#  'fundraisers': 602,
#  'Afghan-Pakistani': 603,
#  'Chatel': 604,
#  'fifteen': 605,
#  'Dans': 606,
#  '50,000': 607,
#  'Tartous': 608,
#  'Oromia': 609,
#  'malicious': 610,
#  'Sangju': 611,
#  'outlined': 612,
#  'year': 613,
#  '1563': 614,
#  'nonexistent': 615,
#  'deposed': 616,
#  'created': 617,
#  'inter-American': 618,
#  '60.3': 619,
#  'Restrepo': 620,
#  'Razuri': 621,
#  '170': 622,
#  'allegedly': 623,
#  'Approaching': 624,
#  'Gonzalo': 625,
#  'UDD': 626,
#  'paperwork': 627,
#  'foreigner': 628,
#  'Hafs': 629,
#  'nine': 630,
#  'intermediaries': 631,
#  '8,956': 632,
#  'third-round': 633,
#  'Taksim': 634,
#  'Hoping': 635,
#  'Valero': 636,
#  'Pentagon': 637,
#  'Castle': 638,
#  'rifles': 639,
#  'Qasab': 640,
#  '8000': 641,
#  'To': 642,
#  'tumbled': 643,
#  'Afder': 644,
#  'sacrificed': 645,
#  '227': 646,
#  'Depot': 647,
#  'WOODCHOPPER': 648,
#  'mixture': 649,
#  'devil': 650,
#  'Edward': 651,
#  'Pakistani-controlled': 652,
#  'co-director': 653,
#  'Cauca': 654,
#  'collectors': 655,
#  'greenhouse': 656,
#  'recapture': 657,
#  'Russian-Iranian': 658,
#  'Making': 659,
#  "VOA'S": 660,
#  'privately-owned': 661,
#  'six-tenths': 662,
#  'bags': 663,
#  'mourning': 664,
#  'pre-storm': 665,
#  'exclaimed': 666,
#  'Florian': 667,
#  '8.7': 668,
#  'operates': 669,
#  'FOWLER': 670,
#  'Usain': 671,
#  'a-quarrelling': 672,
#  'Jumblatt': 673,
#  'Khamail': 674,
#  'championed': 675,
#  'enlist': 676,
#  'H7': 677,
#  'central-leftist': 678,
#  'Preston': 679,
#  'Kumble': 680,
#  '422.5': 681,
#  'Agitation': 682,
#  'Patrick': 683,
#  'oversized': 684,
#  'holster': 685,
#  'Shaffi': 686,
#  'socializing': 687,
#  '30.5': 688,
#  'Rugged': 689,
#  'black': 690,
#  'Afar': 691,
#  'Confederations': 692,
#  'Watched': 693,
#  'solution': 694,
#  'Anchorage': 695,
#  'believe': 696,
#  '14.88': 697,
#  'Salizhan': 698,
#  'Seoul-based': 699,
#  'cigarette': 700,
#  '19.7': 701,
#  'weapon': 702,
#  'Naxalites': 703,
#  'protocols': 704,
#  'radiotherapy': 705,
#  'distinctive': 706,
#  'razor': 707,
#  'Exxon': 708,
#  'hockey': 709,
#  '11-judge': 710,
#  'Vigilant': 711,
#  'Ashdown': 712,
#  'ALL': 713,
#  'Humam': 714,
#  'Malegaon': 715,
#  'accelerated': 716,
#  'differs': 717,
#  'receding': 718,
#  'Lafoole': 719,
#  'burial': 720,
#  'evening': 721,
#  'Wis.': 722,
#  'galaxies': 723,
#  'custodian': 724,
#  'resilience': 725,
#  'Tatiana': 726,
#  'Ceremony': 727,
#  'Caufield': 728,
#  'USA': 729,
#  'recollecting': 730,
#  '245': 731,
#  'deaths': 732,
#  'undermines': 733,
#  'redistribute': 734,
#  'Cohen': 735,
#  'famous': 736,
#  'hide': 737,
#  'Serb': 738,
#  'caregivers': 739,
#  'multi-billion': 740,
#  'Kehla': 741,
#  'bomb-laden': 742,
#  'Sarin': 743,
#  'Bradman': 744,
#  'Services': 745,
#  'Shihab': 746,
#  'Signed': 747,
#  'docked': 748,
#  'Adams': 749,
#  'Cavalese': 750,
#  'treasurer': 751,
#  'power': 752,
#  'Farther': 753,
#  'Ramirez': 754,
#  'seal': 755,
#  'showdowns': 756,
#  'communion': 757,
#  'exposition': 758,
#  'read': 759,
#  'ignorance': 760,
#  '63': 761,
#  'Giuliana': 762,
#  'Mu': 763,
#  'Gerry': 764,
#  'sprout': 765,
#  'Construction': 766,
#  'Carreno': 767,
#  'Booking': 768,
#  '1.24': 769,
#  'Choe': 770,
#  'users': 771,
#  'Guocong': 772,
#  'Howells': 773,
#  'Boko': 774,
#  '1.8': 775,
#  'curling': 776,
#  'Durian': 777,
#  'shelve': 778,
#  'Hitch': 779,
#  'heightening': 780,
#  'Jean': 781,
#  'Gunsmoke': 782,
#  'Selim': 783,
#  'confidently': 784,
#  'Arghandab': 785,
#  'Convention': 786,
#  're-establishment': 787,
#  'deepwater': 788,
#  '25-member': 789,
#  'advised': 790,
#  'wrathful': 791,
#  'criminals': 792,
#  'market-share': 793,
#  'sunk': 794,
#  'Hubble': 795,
#  'Yanbu': 796,
#  'lighting': 797,
#  'psychologically': 798,
#  'Yoshie': 799,
#  'Empire': 800,
#  'SANTOS': 801,
#  'then-Specialist': 802,
#  'Integra': 803,
#  'Deoband': 804,
#  'Jelinek': 805,
#  'reservists': 806,
#  'Zulima': 807,
#  'repeat': 808,
#  'Gotovina': 809,
#  'resolved': 810,
#  'sweets': 811,
#  'persons': 812,
#  'Tennis': 813,
#  'slaughter': 814,
#  '14th-century': 815,
#  'Maaleh': 816,
#  '575': 817,
#  'co-leader': 818,
#  'cities': 819,
#  'Kalamazoo': 820,
#  'sign': 821,
#  'swimmer': 822,
#  'Inquiry': 823,
#  'near-continuous': 824,
#  'swear': 825,
#  'Arshad': 826,
#  'Puteh': 827,
#  'Maghreb': 828,
#  'NBA': 829,
#  '11': 830,
#  'patron': 831,
#  'swearing-in': 832,
#  'OIC': 833,
#  'cleansing': 834,
#  'immobilized': 835,
#  'ill': 836,
#  'Surkh': 837,
#  'stroke': 838,
#  'opposition-led': 839,
#  'sexually': 840,
#  'Bastani': 841,
#  'plotting': 842,
#  'symptoms': 843,
#  'Shamin': 844,
#  'drought': 845,
#  'reemergence': 846,
#  'domain': 847,
#  'Kousalyan': 848,
#  'hijacker': 849,
#  'Studio': 850,
#  'Katarina': 851,
#  'before': 852,
#  'sounds': 853,
#  'mixed': 854,
#  'Vargas': 855,
#  'waiver': 856,
#  '80-year-old': 857,
#  'Frente': 858,
#  'statute': 859,
#  'colony': 860,
#  'guest': 861,
#  'Realignment': 862,
#  'Azimi': 863,
#  'modifies': 864,
#  'unlocked': 865,
#  'Limmt': 866,
#  'Stimulus': 867,
#  'Leah': 868,
#  'recently-unsealed': 869,
#  'Insulza': 870,
#  'precision-guided': 871,
#  'Nigerla': 872,
#  'ash': 873,
#  'pits': 874,
#  'impropriety': 875,
#  'Afewerki': 876,
#  'stand-in': 877,
#  'realized': 878,
#  'refraining': 879,
#  'bounce': 880,
#  'knowledge-based': 881,
#  'Roosevelt': 882,
#  'unverified': 883,
#  'Ahadi': 884,
#  'Oregon': 885,
#  'Dulmatin': 886,
#  'al-Qassam': 887,
#  'tallied': 888,
#  'Quality': 889,
#  'epicenter': 890,
#  'Luxembourg': 891,
#  'federations': 892,
#  'specializes': 893,
#  'counternarcotics': 894,
#  'Saint-Domingue': 895,
#  'between': 896,
#  '13-year-old': 897,
#  'Geo': 898,
#  'chairwoman': 899,
#  'gritty': 900,
#  'Srinigar': 901,
#  'Board': 902,
#  'geographically': 903,
#  'U-2s': 904,
#  'Portoroz': 905,
#  'ties': 906,
#  'gotten': 907,
#  'landmark': 908,
#  'Wafd': 909,
#  'Ri': 910,
#  '34-day': 911,
#  'Bursting': 912,
#  'Acropolis': 913,
#  'analyzing': 914,
#  'sudden': 915,
#  'summary': 916,
#  '250': 917,
#  'fort': 918,
#  'Argentines': 919,
#  'manipulates': 920,
#  'correctness': 921,
#  'Advisor': 922,
#  'moves': 923,
#  'nap': 924,
#  'greats': 925,
#  '09-Nov': 926,
#  'buster': 927,
#  'north-south': 928,
#  'Juventus': 929,
#  'trousers': 930,
#  'water': 931,
#  'protester': 932,
#  'offending': 933,
#  'financially': 934,
#  'sea': 935,
#  '7.3': 936,
#  '#NAME?': 937,
#  '1,75,000': 938,
#  'Anyone': 939,
#  'Cantoni': 940,
#  'Sarkozy': 941,
#  'memorials': 942,
#  'underlings': 943,
#  'carries': 944,
#  'importance': 945,
#  'geese': 946,
#  '71-person': 947,
#  'Parthenon': 948,
#  'Transylvania': 949,
#  'al-Shaer': 950,
#  'self-reliance': 951,
#  'rape': 952,
#  '115': 953,
#  'Correspondent': 954,
#  'Llagostera': 955,
#  'anti-oxidant': 956,
#  'Younous': 957,
#  'corruption': 958,
#  '87th': 959,
#  'feared': 960,
#  'Rosales': 961,
#  'months': 962,
#  'pieces': 963,
#  'skiers': 964,
#  'divides': 965,
#  'buildup': 966,
#  'Settlement': 967,
#  'Sein': 968,
#  'gallon': 969,
#  'adapted': 970,
#  'Kwan': 971,
#  'Khedira': 972,
#  'production': 973,
#  'troop': 974,
#  'one-fifth': 975,
#  'Pokhara': 976,
#  'Aftab': 977,
#  'cry': 978,
#  'newly-built': 979,
#  'Manas': 980,
#  'Wlodzimierz': 981,
#  'Soku': 982,
#  'Henry': 983,
#  'healing': 984,
#  'U-Turn': 985,
#  'economy': 986,
#  'rewrite': 987,
#  'laughable': 988,
#  'Michaella': 989,
#  'Ganiyu': 990,
#  'whiskey': 991,
#  'peacefully': 992,
#  'expedite': 993,
#  'Close': 994,
#  'Feel': 995,
#  'Plans': 996,
#  'Khyber': 997,
#  'irresistable': 998,
#  'prompt': 999,
#  'Guyana': 1000,
#  ...}

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 50)            1758950
#
#  spatial_dropout1d (Spatial  (None, 50, 50)            0
#  Dropout1D)
#
#  bidirectional (Bidirection  (None, 50, 200)           120800
#  al)
#
#  time_distributed (TimeDist  (None, 50, 17)            3417
#  ributed)
#
# =================================================================
# Total params: 1883167 (7.18 MB)
# Trainable params: 1883167 (7.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=2, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=3,
    callbacks=callbacks,
    verbose=1
)
# Out:
# accuracy
# 	training         	 (min:    0.956, max:    0.988, cur:    0.988)
# 	validation       	 (min:    0.980, max:    0.985, cur:    0.985)
# Loss
# 	training         	 (min:    0.038, max:    0.193, cur:    0.038)
# 	validation       	 (min:    0.050, max:    0.072, cur:    0.050)
#
# Epoch 3: val_loss improved from 0.05260 to 0.05028, saving model to model_weights.h5
# 1050/1050 [==============================] - 168s 160ms/step - loss: 0.0382 - accuracy: 0.9883 - val_loss: 0.0503 - val_accuracy: 0.9849
# Wall time: 8min 31s

# %%
model.evaluate(x_test, y_test)
# Out:
# 450/450 [==============================] - 14s 30ms/step - loss: 0.0503 - accuracy: 0.9849
# [0.05027715116739273, 0.9848665595054626]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# 1/1 [==============================] - 1s 928ms/step
# Word           True 	 Pred
#
# ------------------------------
# The            O	O
# United         B-geo	B-geo
# States         I-geo	I-geo
# has            O	O
# 103            O	O
# nuclear        O	O
# power          O	O
# plants         O	O
# in             O	O
# 31             O	B-tim
# states         O	O
# .              O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
# Sriharokota    O	O
