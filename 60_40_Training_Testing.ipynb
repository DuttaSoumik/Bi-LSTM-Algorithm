# %%
#importing libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# C:\Users\SOUMIK\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Tensorflow version: 2.14.0
# GPU detected: []

# %%
#importing dataset
data = pd.read_csv(r"C:\Users\SOUMIK\Desktop\CNER Project\archive\ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
#finding the number of unique words and tags in the corpus
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
#padding the de-duplicated values
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
#padding for tags
tags = list(set(data["Tag"].values))
num_tags = len(tags)
print(num_words, num_tags)
# Out:
# 35179 17

# %%
#Retrieve Sentences and Corresponding Tags
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %%
#Define Mappings between Sentences and Tags
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
word2idx
# Out:
# {'Multan': 1,
#  'totals': 2,
#  'Place': 3,
#  'Nanhai': 4,
#  'Sedibe': 5,
#  'confessions': 6,
#  'Visiting': 7,
#  'Dead': 8,
#  'challenges': 9,
#  'dangerously': 10,
#  'Goodluck': 11,
#  'pretended': 12,
#  'resistant': 13,
#  'corridor': 14,
#  'ITV1': 15,
#  'assess': 16,
#  'eviction': 17,
#  'Al': 18,
#  'al-Qaida-affiliated': 19,
#  'PetroChina': 20,
#  'dragged': 21,
#  'suspends': 22,
#  'Halifax': 23,
#  'supplement': 24,
#  'frozen': 25,
#  'toothfish': 26,
#  'One-party': 27,
#  'earthquake': 28,
#  'Ralston': 29,
#  'LBC': 30,
#  'back-up': 31,
#  '53-minute': 32,
#  'veterinarian': 33,
#  'companies': 34,
#  'handgun': 35,
#  'Jerusalem': 36,
#  'outed': 37,
#  'Apple-Tree': 38,
#  'recycled': 39,
#  'Therefore': 40,
#  'Peacekeeping': 41,
#  'al-Bared': 42,
#  'dramatic': 43,
#  'residences': 44,
#  'PIGEON': 45,
#  'mastery': 46,
#  'Hanover': 47,
#  'lastly': 48,
#  'lucky': 49,
#  'Kite': 50,
#  'spreads': 51,
#  'employ': 52,
#  'let': 53,
#  'urchins': 54,
#  'Stethem': 55,
#  'Caucasian': 56,
#  'Kidd': 57,
#  'marched': 58,
#  'DiCaprio': 59,
#  'virulent': 60,
#  'transparency': 61,
#  'THE': 62,
#  'Yasukuni': 63,
#  'fleece': 64,
#  'Producing': 65,
#  '1.18': 66,
#  'Egeland': 67,
#  'Proved': 68,
#  'contractors': 69,
#  'Lancet': 70,
#  'midfield': 71,
#  'transfusion': 72,
#  'two-thousand': 73,
#  'brigade': 74,
#  'diagnostic': 75,
#  'table': 76,
#  'Arbaeen': 77,
#  'gaining': 78,
#  'sabotaged': 79,
#  'Miami': 80,
#  'Remote': 81,
#  'Silvan': 82,
#  'swap': 83,
#  'stands': 84,
#  'Microsoft': 85,
#  'tycoon': 86,
#  'Cameron': 87,
#  'add': 88,
#  'Government-sponsored': 89,
#  'resent': 90,
#  'reformer': 91,
#  'Archaeologist': 92,
#  'Jalali': 93,
#  'anti-monarchy': 94,
#  'shed': 95,
#  'empowerment': 96,
#  'Thatcher': 97,
#  'poll': 98,
#  'Bududa': 99,
#  'satanic': 100,
#  'consented': 101,
#  'Moldovan': 102,
#  'mark': 103,
#  'Conference': 104,
#  'Fela': 105,
#  'bystander': 106,
#  'hamper': 107,
#  'Jocelerme': 108,
#  'Thousands': 109,
#  'regain': 110,
#  'piano': 111,
#  'Anglo-Leasing': 112,
#  'seemingly': 113,
#  'insurers': 114,
#  'guesthouse': 115,
#  'herding': 116,
#  'tuition': 117,
#  'top-level': 118,
#  'cooled': 119,
#  'hostage-taker': 120,
#  'Cemetery': 121,
#  'far-reaching': 122,
#  'stand': 123,
#  'abbreviations': 124,
#  'al-Libbi': 125,
#  'immunize': 126,
#  'Arg': 127,
#  'contenders': 128,
#  'charming': 129,
#  'domestic': 130,
#  'cordons': 131,
#  '197-page': 132,
#  'escorts': 133,
#  'Ophelia': 134,
#  'commonwealth': 135,
#  'Satterfield': 136,
#  'resettling': 137,
#  'Thamilselvan': 138,
#  'Verveer': 139,
#  'nasty': 140,
#  'Bula': 141,
#  '1867': 142,
#  '85': 143,
#  'scorched': 144,
#  'emphasized': 145,
#  'countrywoman': 146,
#  'coastlines': 147,
#  'commit': 148,
#  'conferred': 149,
#  'lime': 150,
#  'contesting': 151,
#  'successors': 152,
#  'Ratnayke': 153,
#  'endeavoring': 154,
#  'SHEPHERD': 155,
#  'permit': 156,
#  '20-month': 157,
#  'FLEA': 158,
#  'Baramullah': 159,
#  'Kocyigit': 160,
#  'Antoin': 161,
#  'suck': 162,
#  'Portland': 163,
#  'Rosenfeld': 164,
#  'Nomura': 165,
#  'Ballack': 166,
#  'Mississippi': 167,
#  'Co.': 168,
#  'Heavy': 169,
#  '1.2927': 170,
#  'statements': 171,
#  'glimpse': 172,
#  '29-year': 173,
#  'GDR': 174,
#  'calamities': 175,
#  '8,599': 176,
#  'Takhar': 177,
#  'tongue': 178,
#  "n't": 179,
#  'Morag': 180,
#  'road-block': 181,
#  'busiest': 182,
#  'supervises': 183,
#  'Jesper': 184,
#  '21': 185,
#  'Poor': 186,
#  'Palacio': 187,
#  'nearing': 188,
#  'trappers': 189,
#  'CARTER': 190,
#  'Boeta': 191,
#  'Macau-made': 192,
#  'chasing': 193,
#  'Dreamgirls': 194,
#  'Ah': 195,
#  'clarity': 196,
#  'tallied': 197,
#  'edict': 198,
#  'funk': 199,
#  'whereas': 200,
#  'respectfully': 201,
#  '60-member': 202,
#  'US-Canada': 203,
#  'apartment': 204,
#  'pulp': 205,
#  'Robitaille': 206,
#  'climate': 207,
#  'signal': 208,
#  'batch': 209,
#  'Babel': 210,
#  'differing': 211,
#  'feat': 212,
#  '17-year-old': 213,
#  'Belfort': 214,
#  'Koirala': 215,
#  '2,200': 216,
#  'LETSIE': 217,
#  'marketing': 218,
#  'destroy': 219,
#  'what': 220,
#  'Neptune': 221,
#  'Championships': 222,
#  'longest-held': 223,
#  'Jehangir': 224,
#  'acidity': 225,
#  'Mansehra': 226,
#  'technically': 227,
#  'non-approved': 228,
#  'disappointed': 229,
#  'perilous': 230,
#  'al-Kharj': 231,
#  'Tariq': 232,
#  'Yousseff': 233,
#  'disaster': 234,
#  'Volganeft-139': 235,
#  'Chandpur': 236,
#  'Global': 237,
#  'Tax': 238,
#  '89': 239,
#  'Godfather': 240,
#  'eight': 241,
#  'purely': 242,
#  'Europe-wide': 243,
#  'scholars': 244,
#  'Hodan': 245,
#  'land-based': 246,
#  'Balloon': 247,
#  'SPENDTHRIFT': 248,
#  'unmanned': 249,
#  'inequality': 250,
#  'holds': 251,
#  'settled': 252,
#  'Afghan': 253,
#  'glorifies': 254,
#  'Refugee': 255,
#  'Israel-Gaza': 256,
#  'park': 257,
#  'Majtenyi': 258,
#  'Buena': 259,
#  'singing': 260,
#  'Tokugawa': 261,
#  'Confederation': 262,
#  'blindfolded': 263,
#  'Vigilant': 264,
#  'present-day': 265,
#  'decisive': 266,
#  'Perisic': 267,
#  'mine': 268,
#  'adamantly': 269,
#  'charting': 270,
#  '1983': 271,
#  'Sudi': 272,
#  'hospital': 273,
#  'kick-start': 274,
#  'architect': 275,
#  'strife': 276,
#  'statistician': 277,
#  'plummets': 278,
#  'Kamel': 279,
#  '6,40,000': 280,
#  'produced': 281,
#  'seats': 282,
#  'revolver': 283,
#  'nutrient': 284,
#  'Maher': 285,
#  'subscribers': 286,
#  'named': 287,
#  'Initial': 288,
#  'QARASE': 289,
#  'four-year-old': 290,
#  'Axum': 291,
#  'drivers': 292,
#  'Business': 293,
#  'closures': 294,
#  'altercation': 295,
#  'forefront': 296,
#  'Jeremy': 297,
#  'hunters': 298,
#  'Flying': 299,
#  'chauffeurs': 300,
#  'lender': 301,
#  'Simba': 302,
#  'Charter97': 303,
#  'employed': 304,
#  'il': 305,
#  'Nairobi': 306,
#  'Sabbath': 307,
#  'sink': 308,
#  'transmissible': 309,
#  'plaque': 310,
#  'Esperon': 311,
#  '154': 312,
#  'Uninsured': 313,
#  'tolled': 314,
#  'transformed': 315,
#  'if': 316,
#  'efforts': 317,
#  'Mariane': 318,
#  'denouncing': 319,
#  'councils': 320,
#  'Taylor': 321,
#  'interest-rate': 322,
#  'Balaguer': 323,
#  'Pakistani-ruled': 324,
#  'Pointe': 325,
#  'Eagle': 326,
#  'whom': 327,
#  'Lashkar-e-Islam': 328,
#  'rebelled': 329,
#  'Maaouya': 330,
#  'ITV': 331,
#  'banner': 332,
#  'Tiantian': 333,
#  'Turkmen': 334,
#  'Softball': 335,
#  'Pyrenees': 336,
#  'Palnoo': 337,
#  'BANDA': 338,
#  'Akitani-Bob': 339,
#  'state-owned': 340,
#  'ruins': 341,
#  'Schwarzenburg': 342,
#  'worn-out': 343,
#  'farm': 344,
#  'Delgado': 345,
#  'proves': 346,
#  'but': 347,
#  'Dmitrivev': 348,
#  'mingling': 349,
#  '53': 350,
#  'Third': 351,
#  'heart': 352,
#  '1886': 353,
#  'Hearings': 354,
#  'poorly-equipped': 355,
#  'Okram': 356,
#  'badly': 357,
#  'strictly': 358,
#  'Maritime': 359,
#  'tenor': 360,
#  'denies': 361,
#  'Huot': 362,
#  'warm-up': 363,
#  '85,000': 364,
#  'Soderling': 365,
#  'disrupted': 366,
#  'Mirdamadi': 367,
#  'surveying': 368,
#  'regrouped': 369,
#  'length': 370,
#  'Pakistan-Afghanistan': 371,
#  'Mlada': 372,
#  'most-widely': 373,
#  'clogged': 374,
#  'Bern': 375,
#  'Punjab': 376,
#  'tsunamis': 377,
#  'bargain': 378,
#  'stand-by': 379,
#  '87.61': 380,
#  'Mihtarlam': 381,
#  'umpire': 382,
#  'unfiltered': 383,
#  'inspects': 384,
#  'neurosurgeon': 385,
#  'aiding': 386,
#  'Host': 387,
#  'Abbott': 388,
#  'Boonyaratglin': 389,
#  'Corporation': 390,
#  'encephalopathy': 391,
#  'hitting': 392,
#  'Ciampi': 393,
#  'Borcz': 394,
#  'sediment': 395,
#  'containment': 396,
#  'Valdes': 397,
#  'villagers': 398,
#  'travel': 399,
#  'Die': 400,
#  'monitored': 401,
#  'incidences': 402,
#  'Siberian': 403,
#  'Servants': 404,
#  'Viread': 405,
#  'unprepared': 406,
#  'revenue': 407,
#  'Caymans': 408,
#  '1971': 409,
#  'hurts': 410,
#  'refrigerated': 411,
#  'Itno': 412,
#  '187': 413,
#  'Miramax': 414,
#  'Blueberry': 415,
#  'wal': 416,
#  'Mohammed': 417,
#  'Hills': 418,
#  'Mashaie': 419,
#  'Frédéric': 420,
#  'Marco': 421,
#  'meant': 422,
#  'amounted': 423,
#  'Chambliss': 424,
#  'Vries': 425,
#  'astrology': 426,
#  'Fund': 427,
#  'icy': 428,
#  'CPPCC': 429,
#  'Multinational': 430,
#  'waited': 431,
#  'Witnesses': 432,
#  'river': 433,
#  'enact': 434,
#  'climbing': 435,
#  'jumpstart': 436,
#  'criticizing': 437,
#  'internal': 438,
#  'Ivica': 439,
#  'Deshu': 440,
#  'Anglo-Irish': 441,
#  'proficiency': 442,
#  'Gerry': 443,
#  '3,72,000': 444,
#  'These': 445,
#  '7115': 446,
#  'consumed': 447,
#  'winter': 448,
#  'quench': 449,
#  'manifestation': 450,
#  'Yilmaz': 451,
#  'Awards': 452,
#  'drives': 453,
#  'levy': 454,
#  'Return': 455,
#  'unsealed': 456,
#  'Playing': 457,
#  'speculators': 458,
#  'post-Taleban': 459,
#  'fine-tuning': 460,
#  'nausea': 461,
#  'Dee': 462,
#  'earnestly': 463,
#  'marry': 464,
#  'Hillah': 465,
#  'elimination': 466,
#  'catcher': 467,
#  'Llasa': 468,
#  '1990': 469,
#  'p.m.': 470,
#  'incarceration': 471,
#  'cartoonists': 472,
#  'on-and-off': 473,
#  'feels': 474,
#  'Mikheil': 475,
#  'Seven': 476,
#  'DTP': 477,
#  'NZ': 478,
#  'pushing': 479,
#  'saddened': 480,
#  'Rotterdam': 481,
#  'Asia-Europe': 482,
#  'Ghalib': 483,
#  'Junoon': 484,
#  'Quartet': 485,
#  'Liberia': 486,
#  'nominated': 487,
#  'Hispanics': 488,
#  'Yankham': 489,
#  'objectionable': 490,
#  'looped': 491,
#  'seismological': 492,
#  'pain': 493,
#  'centimeters': 494,
#  'wool': 495,
#  'Nigerla': 496,
#  'UNICEF': 497,
#  'disparate': 498,
#  'original': 499,
#  'one-half': 500,
#  'rely': 501,
#  'Domm': 502,
#  'Interest': 503,
#  'Mekong': 504,
#  'Radhia': 505,
#  'pinpoint': 506,
#  'record-breaking': 507,
#  'Old': 508,
#  'S.p.A.': 509,
#  '1922': 510,
#  'Al-Zawahiri': 511,
#  'Kazimierz': 512,
#  'stormed': 513,
#  'Sans': 514,
#  'northeast': 515,
#  'year-round': 516,
#  'beat': 517,
#  'Sheehan': 518,
#  'cutthroat': 519,
#  'brawl': 520,
#  'biblical': 521,
#  'HARIRI': 522,
#  'Wiig': 523,
#  'abortion': 524,
#  'Allawi': 525,
#  'court-martial': 526,
#  'Material': 527,
#  'Grenoble': 528,
#  '676': 529,
#  'cited': 530,
#  'revoke': 531,
#  'Spielberg': 532,
#  'subprime': 533,
#  'Palpa': 534,
#  'high-rise': 535,
#  'spiritual': 536,
#  'Zablocki': 537,
#  'intervening': 538,
#  'late-night': 539,
#  'Jufeng': 540,
#  'Sulawesi': 541,
#  'Baghdad': 542,
#  'greatness': 543,
#  'trainers': 544,
#  'previously-owned': 545,
#  'Realtors': 546,
#  'suspending': 547,
#  'contaminate': 548,
#  'solemly': 549,
#  'package': 550,
#  'Chaldean': 551,
#  'Abdirahman': 552,
#  'organize': 553,
#  'Karasu': 554,
#  'Murungaru': 555,
#  'conductor': 556,
#  'shocking': 557,
#  'Ruini': 558,
#  'yearly': 559,
#  'Rezko': 560,
#  '295': 561,
#  'restraints': 562,
#  'blared': 563,
#  'U.N.-backed': 564,
#  'Bernazzani': 565,
#  'Charlie': 566,
#  'taxation': 567,
#  'Sud': 568,
#  'alertness': 569,
#  'Dwayne': 570,
#  'rapper': 571,
#  'logistical': 572,
#  'chronicles': 573,
#  'bribing': 574,
#  'Hanun': 575,
#  'execute': 576,
#  'knows': 577,
#  'Admhaiyah': 578,
#  'Al-Mukmin': 579,
#  'Assad': 580,
#  'Kasparov': 581,
#  'metropolis': 582,
#  'Adhaim': 583,
#  'Bashir': 584,
#  'Eurozone': 585,
#  'Castillo': 586,
#  'Nidal': 587,
#  'Otto': 588,
#  '4-0': 589,
#  'Forward': 590,
#  'Wasit': 591,
#  'endangered': 592,
#  'NATO': 593,
#  'nor': 594,
#  'MENA': 595,
#  'idle': 596,
#  'hometown': 597,
#  '3:34:33.2': 598,
#  'thwarted': 599,
#  'S': 600,
#  'Hampton': 601,
#  'when': 602,
#  'MPRP': 603,
#  'prop': 604,
#  'airing': 605,
#  'purification': 606,
#  'Trafficking': 607,
#  'destiny': 608,
#  'Complicated': 609,
#  'lead': 610,
#  'shot': 611,
#  'contain': 612,
#  'depressing': 613,
#  'uranium-enrichment': 614,
#  'Miran': 615,
#  'earthen': 616,
#  'fades': 617,
#  'Abraham': 618,
#  'Line': 619,
#  'Jackdaw': 620,
#  'slippery': 621,
#  'Reno': 622,
#  'approaches': 623,
#  'Rights': 624,
#  'pep': 625,
#  'underperforming': 626,
#  'caution': 627,
#  'Kharazi': 628,
#  'vie': 629,
#  'Yunnan': 630,
#  'Evan': 631,
#  'inspector': 632,
#  'Tree': 633,
#  'Gaza-Egyptian': 634,
#  'interior': 635,
#  'redraw': 636,
#  'attends': 637,
#  'disappointment': 638,
#  'Welfare': 639,
#  'bomblets': 640,
#  'Rovnag': 641,
#  'Koukalova': 642,
#  'Peoples': 643,
#  'reassert': 644,
#  'Kennedys': 645,
#  'third-in-command': 646,
#  '16.2': 647,
#  'Inspired': 648,
#  'deeper': 649,
#  '1906': 650,
#  'hundreds': 651,
#  'assume': 652,
#  'anti-free': 653,
#  'Kato': 654,
#  'ravine': 655,
#  '34.5': 656,
#  'animists': 657,
#  'Sydney': 658,
#  'Pledge': 659,
#  'military': 660,
#  'majority': 661,
#  'detection': 662,
#  'non-perishable': 663,
#  'Category': 664,
#  'Bilis': 665,
#  '@dalailama': 666,
#  'Urbi': 667,
#  'Rogers': 668,
#  'disputing': 669,
#  'months-long': 670,
#  'Dent': 671,
#  'U.S': 672,
#  'provisionally': 673,
#  'roamed': 674,
#  'copes': 675,
#  'incur': 676,
#  'cut': 677,
#  'induce': 678,
#  'H&M': 679,
#  'Syrian-dominated': 680,
#  'Fatherland': 681,
#  'sunrise': 682,
#  'Galo': 683,
#  'al-Sadr': 684,
#  'where': 685,
#  '41,000': 686,
#  '86': 687,
#  'Knut': 688,
#  'Petroleos': 689,
#  'demarcation': 690,
#  'NSC': 691,
#  '24-hour': 692,
#  'doubtful': 693,
#  'resource': 694,
#  'anti-Israeli': 695,
#  'Wildlife': 696,
#  'Ukrainians': 697,
#  'fluid': 698,
#  'light': 699,
#  'centrist': 700,
#  'forgetting': 701,
#  'Char': 702,
#  'Pin': 703,
#  'subsistence-based': 704,
#  'edged': 705,
#  'floodwalls': 706,
#  'Alan': 707,
#  'adviser': 708,
#  'Reinsurance': 709,
#  'schooled': 710,
#  'pass': 711,
#  'Warlords': 712,
#  'supplier': 713,
#  'specially-built': 714,
#  'toxic': 715,
#  'pitcher': 716,
#  'booming': 717,
#  'reestablishing': 718,
#  'al-Hanifa': 719,
#  'portico': 720,
#  'serve': 721,
#  'Shopping': 722,
#  'watchdog': 723,
#  'strangle': 724,
#  'moderately': 725,
#  'meddling': 726,
#  're-deployment': 727,
#  'Adil': 728,
#  'variation': 729,
#  'Infrared': 730,
#  'equipment': 731,
#  'indolent': 732,
#  'Berkovsky': 733,
#  'provincial': 734,
#  'embarrassed': 735,
#  'Shell': 736,
#  '100-meter': 737,
#  'Schudrich': 738,
#  'Cassini': 739,
#  'transactions': 740,
#  'unique': 741,
#  'Controversy': 742,
#  'humiliated': 743,
#  'withstood': 744,
#  'nutmeg': 745,
#  'hung': 746,
#  'Hurriyat': 747,
#  'peak': 748,
#  'Pan': 749,
#  'holiday': 750,
#  'hypocrisy': 751,
#  'devils': 752,
#  'scratched': 753,
#  'Lynn': 754,
#  'margin': 755,
#  'London': 756,
#  'targets': 757,
#  'wider': 758,
#  '10-Jan': 759,
#  'Over': 760,
#  'apartments': 761,
#  'Ulus': 762,
#  'Okie': 763,
#  'stint': 764,
#  'MOHAMMED': 765,
#  'inefficiencies': 766,
#  'dilapidated': 767,
#  'corner': 768,
#  'Mudasir': 769,
#  'enlist': 770,
#  'Segway': 771,
#  'Founded': 772,
#  'influenced': 773,
#  'gunboats': 774,
#  'Andrey': 775,
#  'providers': 776,
#  'Natsios': 777,
#  'withdraws': 778,
#  'disapproved': 779,
#  'Delegate': 780,
#  'Kayhan': 781,
#  'civilian': 782,
#  'expose': 783,
#  'theme': 784,
#  'bishops': 785,
#  'assassination': 786,
#  'Rocca': 787,
#  'multi-candidate': 788,
#  'Listen': 789,
#  'ample': 790,
#  'Dae': 791,
#  'Balaj': 792,
#  'inconceivable': 793,
#  'Brazil': 794,
#  'Mary': 795,
#  'smashed': 796,
#  'Tenerife': 797,
#  'frees': 798,
#  'propagandists': 799,
#  'Kambakhsh': 800,
#  '71': 801,
#  '1,125': 802,
#  'Anbar': 803,
#  'awkwardly': 804,
#  'al-Zahar': 805,
#  'mutilating': 806,
#  'apprehend': 807,
#  'commonly': 808,
#  'airdrop': 809,
#  'fees': 810,
#  '131': 811,
#  'phrases': 812,
#  'pessimist': 813,
#  'obsessed': 814,
#  'goes': 815,
#  'probing': 816,
#  'Binjie': 817,
#  '41,53,237': 818,
#  'screening': 819,
#  'Udhampur': 820,
#  'discourage': 821,
#  'hysterectomy': 822,
#  'York': 823,
#  'bolivar': 824,
#  'approving': 825,
#  'Latortue': 826,
#  'fourth': 827,
#  'indicted': 828,
#  'frisked': 829,
#  'adhere': 830,
#  'Italians': 831,
#  'Samad': 832,
#  'swerved': 833,
#  'Qubad': 834,
#  '69th': 835,
#  'Unions': 836,
#  'Abdul-Mahdi': 837,
#  'redistribute': 838,
#  'slower': 839,
#  'Jassar': 840,
#  'Brownback': 841,
#  'Currently': 842,
#  'Soir': 843,
#  'sheltering': 844,
#  'conscience': 845,
#  'fraudulent': 846,
#  'perceive': 847,
#  'Polonnaruwa': 848,
#  'inductees': 849,
#  'Unpredictable': 850,
#  'Diwaniyah': 851,
#  'eruption': 852,
#  'enacts': 853,
#  'Zawahiri': 854,
#  'modest': 855,
#  'Boasting': 856,
#  'privately-run': 857,
#  '0.5': 858,
#  'human': 859,
#  'functions': 860,
#  'Melnichenko': 861,
#  'sandbag-reinforced': 862,
#  'disqualification': 863,
#  'faultless': 864,
#  'Clinton': 865,
#  'San': 866,
#  'interagency': 867,
#  'midair': 868,
#  'Colleen': 869,
#  'PRINCE': 870,
#  'lapses': 871,
#  'leave': 872,
#  'clarifies': 873,
#  'Swing': 874,
#  '104.1': 875,
#  'partnership': 876,
#  'Nissan': 877,
#  'shopkeeper': 878,
#  '2016': 879,
#  'unemployed': 880,
#  'divided': 881,
#  'pickle-fork': 882,
#  'Sangakkara': 883,
#  'stream': 884,
#  'limited-over': 885,
#  'Rate': 886,
#  'CNBC': 887,
#  'Olaf': 888,
#  'two-point-seven': 889,
#  'weekly': 890,
#  'Hamilton': 891,
#  'Geofizyka': 892,
#  'western-style': 893,
#  '80-page': 894,
#  'prisons': 895,
#  'supplanted': 896,
#  'A380': 897,
#  'vindicates': 898,
#  'Butch': 899,
#  'Military': 900,
#  'notorious': 901,
#  'accounted': 902,
#  'leveled': 903,
#  'misled': 904,
#  'Ousamane': 905,
#  'e-commerce': 906,
#  'Sidique': 907,
#  '1.7': 908,
#  'Shaharyar': 909,
#  'expedite': 910,
#  '1634': 911,
#  'Bermuda': 912,
#  'ancestry': 913,
#  'Chittagong': 914,
#  'TRAVELERS': 915,
#  'Makin': 916,
#  'flared': 917,
#  'obtainable': 918,
#  'Metro-Goldwyn-Mayer': 919,
#  'overruled': 920,
#  'stores': 921,
#  'unionist': 922,
#  'join': 923,
#  'Bonds': 924,
#  'directive': 925,
#  'dangerous': 926,
#  'basically': 927,
#  'anticipation': 928,
#  'Hasegawa': 929,
#  'Nazarov': 930,
#  'translate': 931,
#  'totally': 932,
#  'astronaut': 933,
#  'demonstration': 934,
#  'is': 935,
#  'Petro': 936,
#  'Mirror': 937,
#  'discriminating': 938,
#  'Filip': 939,
#  '87': 940,
#  'abetting': 941,
#  'Manchester': 942,
#  'closed-circuit': 943,
#  'claimed': 944,
#  'upcoming': 945,
#  'defending': 946,
#  'describes': 947,
#  'al-Fitr': 948,
#  'expertise': 949,
#  'Oslo': 950,
#  'Gunbattles': 951,
#  'Garhi': 952,
#  '5.9': 953,
#  'objections': 954,
#  'Moi': 955,
#  'Zedong': 956,
#  'heap': 957,
#  'identifying': 958,
#  'kinds': 959,
#  'stomach': 960,
#  'meltdown': 961,
#  'spilling': 962,
#  'European-built': 963,
#  'Five': 964,
#  'Mardan': 965,
#  'WAEMU': 966,
#  'forgiveness': 967,
#  'widely': 968,
#  'indisputably': 969,
#  'asset': 970,
#  'shaping': 971,
#  'Carabobo': 972,
#  'Patrick': 973,
#  'Babri': 974,
#  'Karliova': 975,
#  'Moratinos': 976,
#  'environments': 977,
#  'boiled': 978,
#  'airfare': 979,
#  'co-chaired': 980,
#  'hid': 981,
#  'viewers': 982,
#  'venomous': 983,
#  'Eisenman': 984,
#  'Topol-M': 985,
#  'Baloyi': 986,
#  'selling': 987,
#  'Raven': 988,
#  'Portman': 989,
#  'Petter': 990,
#  'Kalla': 991,
#  'Zalinge': 992,
#  'booster': 993,
#  'dazzling': 994,
#  'unaffiliated': 995,
#  'Jokers': 996,
#  'discredit': 997,
#  'visits': 998,
#  'assisting': 999,
#  'lawmaker': 1000,
#  ...}

# %%
#creating histogram
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
#Padding Input Sentences and Creating Train/Test Splits
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
#splitting the data into 80-20
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %%
#creating bi-directional LSTM model
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 50)            1758950
#
#  spatial_dropout1d (Spatial  (None, 50, 50)            0
#  Dropout1D)
#
#  bidirectional (Bidirection  (None, 50, 200)           120800
#  al)
#
#  time_distributed (TimeDist  (None, 50, 17)            3417
#  ributed)
#
# =================================================================
# Total params: 1883167 (7.18 MB)
# Trainable params: 1883167 (7.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
#Train the Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=2, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=3,
    callbacks=callbacks,
    verbose=1
)
# Out:
# accuracy
# 	training         	 (min:    0.951, max:    0.988, cur:    0.988)
# 	validation       	 (min:    0.977, max:    0.985, cur:    0.985)
# Loss
# 	training         	 (min:    0.040, max:    0.217, cur:    0.040)
# 	validation       	 (min:    0.051, max:    0.087, cur:    0.051)
#
# Epoch 3: val_loss improved from 0.05601 to 0.05145, saving model to model_weights.h5
# 900/900 [==============================] - 146s 163ms/step - loss: 0.0403 - accuracy: 0.9878 - val_loss: 0.0515 - val_accuracy: 0.9849
# Wall time: 7min 40s

# %%
#Evaluate Named Entity Recognition Model
model.evaluate(x_test, y_test)
# Out:
# 600/600 [==============================] - 19s 31ms/step - loss: 0.0515 - accuracy: 0.9849
# [0.05145227164030075, 0.9848623871803284]

# %%
#Prediction
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# 1/1 [==============================] - 1s 939ms/step
# Word           True 	 Pred
#
# ------------------------------
# The            O	O
# United         B-geo	B-geo
# States         I-geo	I-geo
# has            O	O
# 103            O	O
# nuclear        O	O
# power          O	O
# plants         O	O
# in             O	O
# 31             O	B-tim
# states         O	O
# .              O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
# redeem         O	O
